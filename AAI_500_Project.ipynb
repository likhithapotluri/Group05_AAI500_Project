# %% [markdown]
# <a href="https://colab.research.google.com/github/likhithapotluri/Group05_AAI500_Project/blob/main/AAI_500_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Predicting and Understanding Factors Affecting Secondary Student Performance
# ## A Statistical and Machine Learning Approach
#
# ### Project Overview
#
# Academic performance is influenced by a combination of demographic characteristics, learning behaviors, support systems, and environmental factors. Understanding these relationships is important for identifying students at risk of academic underperformance and designing targeted intervention strategies. Traditional statistical methods provide interpretable insights into the relationships between predictors and outcomes, while modern machine learning techniques offer enhanced predictive capabilities by capturing complex nonlinear patterns and interactions.
#
# This project investigates the determinants of secondary student academic performance using a dataset containing approximately 2,392 student records and multiple explanatory variables related to demographics, study habits, parental support, tutoring participation, extracurricular engagement, and attendance behavior. The primary outcome variable is **Grade Point Average (GPA)**, while **GradeClass** serves as a categorical indicator of academic achievement levels.
#
# Unlike traditional GPA prediction studies that focus solely on predictive accuracy, this analysis combines statistical inference, machine learning, clustering, and probabilistic modeling to provide both explanatory and predictive insights. Particular emphasis is placed on understanding **interaction effects**, **student heterogeneity**, and **intervention-oriented decision support** through Bayesian Networks and cluster-based profiling.
#
#
# ## Research Question
#
# **What are the key statistical and interactive factors influencing student GPA, and how can robust predictive models be developed while accounting for uncertainty, demographic variation, and student heterogeneity?**
#
#
# ## Research Objectives
#
# The objectives of this project are:
#
# 1. Investigate the statistical relationships between demographic, behavioral, and support-related variables and academic performance.
# 2. Identify the strongest predictors of GPA using regression and machine learning approaches.
# 3. Evaluate whether support-related variables moderate the influence of attendance and study behavior.
# 4. Develop predictive models for both continuous (GPA) and categorical (GradeClass) outcomes.
# 5. Discover meaningful student archetypes using unsupervised clustering techniques.
# 6. Construct Bayesian Network models for probabilistic reasoning and intervention analysis.
# 7. Assess model fairness and performance across demographic groups.
#
# ## Dataset Description
#
# The dataset consists of approximately **2,392 student observations** and contains a mixture of numerical and categorical variables.
#
# ### Demographic Variables
# - Age
# - Gender
# - Ethnicity
# - Parental Education
#
# ### Academic Behavior Variables
# - StudyTimeWeekly
# - Absences
# - Tutoring Participation
#
# ### Support and Engagement Variables
# - Parental Support
# - Extracurricular Activities
# - Sports Participation
# - Music Participation
# - Volunteering Activities
#
# ### Outcome Variables
# - GPA (continuous target variable)
# - GradeClass (categorical achievement class)
#
# To enhance analytical capability, additional derived variables were created during preprocessing, including:
#
# - Support Index
# - Activity Diversity Score
# - Absence Rate
# - Interaction Terms
#   - ParentalSupport × Absences
#   - StudyTimeWeekly × Gender
#
#
# ## Analytical Framework
#
# The project combines techniques from statistics, machine learning, and probabilistic modeling.
#
# ### Statistical Analysis
# - Descriptive Statistics
# - Probability Distributions
# - Confidence Intervals
# - Hypothesis Testing
# - Bootstrap Sampling
# - Central Limit Theorem Demonstration
#
# ### Predictive Modeling
# - Multiple Linear Regression
# - Logistic Regression
# - Random Forest Classification
# - Multi-Class Classification
#
# ### Unsupervised Learning
# - K-Means Clustering
# - Student Archetype Identification
#
# ### Probabilistic Modeling
# - Bayesian Networks
# - Conditional Probability Inference
# - Intervention Simulation
#
# ### Explainability and Interpretation
# - Feature Importance Analysis
# - Interaction Effects
# - Scenario-Based Intervention Analysis
#
# ## Research Hypotheses
#
# The following hypotheses are evaluated throughout the study:
#
# 1. Students with greater weekly study time achieve significantly higher GPA values.
#
# 2. Student absences are negatively associated with academic performance.
#
# 3. Parental support moderates the relationship between absenteeism and GPA.
#
# 4. Academic performance differs significantly across demographic groups.
#
# 5. Distinct student archetypes exist and can be identified through clustering analysis.
#
#
# ## Expected Contributions
#
# This project contributes to educational analytics in three ways:
#
# 1. **Prediction:** Develop accurate models for identifying academic performance outcomes.
# 2. **Interpretation:** Quantify the influence of key academic and support-related factors.
# 3. **Decision Support:** Use clustering and Bayesian Networks to provide actionable recommendations for targeted educational interventions.
#
# The results are intended to support educators, counselors, and policymakers in designing data-driven strategies that improve student outcomes while accounting for differences across student populations.

# %%
# !pip -q install pgmpy shap xgboost

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, roc_curve, confusion_matrix, silhouette_score,
    mean_squared_error, mean_absolute_error, r2_score
)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans

import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.stattools import durbin_watson
from statsmodels.graphics.gofplots import qqplot

from pgmpy.models import BayesianNetwork, DiscreteBayesianNetwork
from pgmpy.estimators import BayesianEstimator
from pgmpy.inference import VariableElimination

sns.set_theme(style="ticks", palette="muted")
plt.rcParams["figure.dpi"] = 110

RANDOM_ANCHOR = 42
# Out:
# GPA: W=0.9838, p=0.0000
# StudyTimeWeekly: W=0.9600, p=0.0000
# Absences: W=0.9557, p=0.0000

# %% [markdown]
# ## Loading Dataset
#
# ## Dataset Overview
#
# The dataset contains 2,392 student observations and multiple explanatory variables related to demographics, study behavior, parental support, and extracurricular participation.
#
# ### Input Variables
# - Age
# - Gender
# - Ethnicity
# - ParentalEducation
# - StudyTimeWeekly
# - Absences
# - Tutoring
# - ParentalSupport
# - Extracurricular
# - Sports
# - Music
# - Volunteering
#
# ### Target Variables
# - GPA (continuous)
# - GradeClass (categorical)

# %%
df = pd.read_csv("/content/Student Performance Data.csv")
if "enriched_dataset" not in globals():
    enriched_dataset = df.copy()

print("Shape:", enriched_dataset.shape)
display(enriched_dataset.head())
print(enriched_dataset.info())
# Out:
# Shape: (2392, 23)
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  ...       GPA  \
# 0         7         1                2                0  ...  2.929196
# 1         0         0                1                0  ...  3.042915
# 2        26         0                2                0  ...  0.112602
# 3        14         0                3                1  ...  2.054218
# 4        17         1                3                0  ...  1.288061
#
#    GradeClass  Absence_Rate  Support_Index  Activity_Diversity  \
# 0           2      0.038889              3                   1
# 1           1      0.000000              1                   0
# 2           4      0.144444              2                   0
# 3           3      0.077778              3                   1
# 4           4      0.094444              4                   0
#
#    Inter_Support_x_Absences  Inter_StudyTime_x_Gender  StudyTime_Bin  \
# 0                        14                 19.833723           High
# 1                         0                  0.000000           High
# 2                        52                  0.000000            Low
# 3                        42                 10.028829         Medium
# 4                        51                  4.672495            Low
#
#    High_Performer  Cluster_ID
# 0               0           1
# 1               1           1
# 2               0           0
# 3               0           1
# 4               0           0
#
# [5 rows x 23 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   StudentID                 2392 non-null   int64
#  1   Age                       2392 non-null   int64
#  2   Gender                    2392 non-null   int64
#  3   Ethnicity                 2392 non-null   int64
#  4   ParentalEducation         2392 non-null   int64
#  5   StudyTimeWeekly           2392 non-null   float64
#  6   Absences                  2392 non-null   int64
#  7   Tutoring                  2392 non-null   int64
#  8   ParentalSupport           2392 non-null   int64
#  9   Extracurricular           2392 non-null   int64
#  10  Sports                    2392 non-null   int64
#  11  Music                     2392 non-null   int64
#  12  Volunteering              2392 non-null   int64
#  13  GPA                       2392 non-null   float64
#  14  GradeClass                2392 non-null   int64
#  15  Absence_Rate              2392 non-null   float64
#  16  Support_Index             2392 non-null   int64
#  17  Activity_Diversity        2392 non-null   int64
#  18  Inter_Support_x_Absences  2392 non-null   int64
#  19  Inter_StudyTime_x_Gender  2392 non-null   float64
#  20  StudyTime_Bin             2392 non-null   category
#  21  High_Performer            2392 non-null   int64
#  22  Cluster_ID                2392 non-null   int32
# dtypes: category(1), float64(4), int32(1), int64(17)
# memory usage: 404.4 KB
# None

# %% [markdown]
# ## Data Cleaning and Preparation
# - Handle missing values
# - Encode categorical variables
# - Create derived features
# - Prepare interaction terms

# %%
print("Missing values per column:")
print(enriched_dataset.isna().sum().sort_values(ascending=False).head(20))

# Fill numeric with median, categorical with mode
for col in enriched_dataset.columns:
    if enriched_dataset[col].dtype in ["float64", "int64"]:
        enriched_dataset[col] = enriched_dataset[col].fillna(enriched_dataset[col].median())
    else:
        enriched_dataset[col] = enriched_dataset[col].fillna(enriched_dataset[col].mode()[0])

# Encode categorical columns
categorical_cols = [
    "Gender", "Ethnicity", "ParentalEducation",
    "Tutoring", "Extracurricular", "Sports", "Music", "Volunteering"
]

for col in categorical_cols:
    if col in enriched_dataset.columns and enriched_dataset[col].dtype == "object":
        enriched_dataset[col] = pd.Categorical(enriched_dataset[col]).codes

# Feature engineering
if "Absence_Rate" not in enriched_dataset.columns:
    enriched_dataset["Absence_Rate"] = enriched_dataset["Absences"] / 180.0

if "Support_Index" not in enriched_dataset.columns:
    enriched_dataset["Support_Index"] = enriched_dataset["ParentalSupport"] + enriched_dataset["Tutoring"]

if "Activity_Diversity" not in enriched_dataset.columns:
    enriched_dataset["Activity_Diversity"] = (
        enriched_dataset["Extracurricular"] +
        enriched_dataset["Sports"] +
        enriched_dataset["Music"] +
        enriched_dataset["Volunteering"]
    )

if "Inter_Support_x_Absences" not in enriched_dataset.columns:
    enriched_dataset["Inter_Support_x_Absences"] = (
        enriched_dataset["ParentalSupport"] * enriched_dataset["Absences"]
    )

if "Inter_StudyTime_x_Gender" not in enriched_dataset.columns:
    enriched_dataset["Inter_StudyTime_x_Gender"] = (
        enriched_dataset["StudyTimeWeekly"] * enriched_dataset["Gender"]
    )

if "StudyTime_Bin" not in enriched_dataset.columns:
    enriched_dataset["StudyTime_Bin"] = pd.cut(
        enriched_dataset["StudyTimeWeekly"],
        bins=3,
        labels=["Low", "Medium", "High"]
    )

if "High_Performer" not in enriched_dataset.columns:
    enriched_dataset["High_Performer"] = (enriched_dataset["GPA"] >= 3.0).astype(int)

print("Cleaning and feature engineering complete.")
# Out:
# Missing values per column:
# StudentID                   0
# Age                         0
# Gender                      0
# Ethnicity                   0
# ParentalEducation           0
# StudyTimeWeekly             0
# Absences                    0
# Tutoring                    0
# ParentalSupport             0
# Extracurricular             0
# Sports                      0
# Music                       0
# Volunteering                0
# GPA                         0
# GradeClass                  0
# Absence_Rate                0
# Support_Index               0
# Activity_Diversity          0
# Inter_Support_x_Absences    0
# Inter_StudyTime_x_Gender    0
# dtype: int64
# Cleaning and feature engineering complete.

# %% [markdown]
# ## Exploratory Data Analysis
# - Descriptive statistics
# - Distribution checks
# - Correlation analysis
# - Group comparisons

# %%
from scipy.stats import shapiro

for col in ["GPA","StudyTimeWeekly","Absences"]:
    stat,p = shapiro(enriched_dataset[col])
    print(f"{col}: W={stat:.4f}, p={p:.4f}")

eda_vars = ["GPA", "StudyTimeWeekly", "Absences"]

summary = enriched_dataset[eda_vars].describe().T
summary["median"] = enriched_dataset[eda_vars].median()
summary["skew"] = enriched_dataset[eda_vars].skew()
summary["kurtosis"] = enriched_dataset[eda_vars].kurtosis()

display(summary.round(4))

for col in eda_vars:
    plt.figure(figsize=(6, 4))
    sns.histplot(enriched_dataset[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.tight_layout()
    plt.show()

plt.figure(figsize=(7, 5))
sns.boxplot(data=enriched_dataset, x="ParentalEducation", y="GPA")
plt.title("GPA by Parental Education")
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 6))
corr_cols = [
    "GPA", "StudyTimeWeekly", "Absences", "ParentalSupport",
    "Tutoring", "Support_Index", "Activity_Diversity", "Absence_Rate"
]
sns.heatmap(enriched_dataset[corr_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
# Out:
# GPA: W=0.9838, p=0.0000
# StudyTimeWeekly: W=0.9600, p=0.0000
# Absences: W=0.9557, p=0.0000
#                   count     mean     std     min     25%      50%      75%  \
# GPA              2392.0   1.9062  0.9152  0.0000  1.1748   1.8934   2.6222
# StudyTimeWeekly  2392.0   9.7720  5.6528  0.0011  5.0431   9.7054  14.4084
# Absences         2392.0  14.5414  8.4674  0.0000  7.0000  15.0000  22.0000
#
#                      max   median    skew  kurtosis
# GPA               4.0000   1.8934  0.0145   -0.8633
# StudyTimeWeekly  19.9781   9.7054  0.0501   -1.1357
# Absences         29.0000  15.0000 -0.0260   -1.1762

# %% [markdown]
# ### Interpretation
#
# The heatmap indicates positive associations between GPA and StudyTimeWeekly, while absences show a negative relationship with academic performance. Support-related variables also demonstrate moderate positive correlations with GPA.

# %% [markdown]
# ## Statistical Inference
# - Hypothesis tests
# - Effect sizes
# - Sampling distribution / CLT demonstration

# %%
def cohens_d(x, y):
    x = np.asarray(x)
    y = np.asarray(y)
    nx, ny = len(x), len(y)
    pooled_sd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / (nx + ny - 2))
    return (x.mean() - y.mean()) / pooled_sd if pooled_sd != 0 else np.nan

def cramers_v(conf_matrix):
    chi2 = stats.chi2_contingency(conf_matrix)[0]
    n = conf_matrix.sum().sum()
    r, c = conf_matrix.shape
    return np.sqrt(chi2 / (n * (min(r - 1, c - 1)))) if n > 0 else np.nan

# Gender vs GPA
gender_groups = enriched_dataset["Gender"].dropna().unique()
gender_samples = [enriched_dataset.loc[enriched_dataset["Gender"] == g, "GPA"] for g in gender_groups]
if len(gender_groups) == 2:
    t_stat, p_val = stats.ttest_ind(gender_samples[0], gender_samples[1], equal_var=False)
    d_val = cohens_d(gender_samples[0], gender_samples[1])
    print(f"Gender vs GPA | t={t_stat:.4f}, p={p_val:.4e}, Cohen's d={d_val:.4f}")
else:
    f_stat, p_val = stats.f_oneway(*gender_samples)
    print(f"Gender vs GPA | ANOVA F={f_stat:.4f}, p={p_val:.4e}")

# Ethnicity vs GPA
ethnicity_groups = enriched_dataset["Ethnicity"].dropna().unique()
ethnicity_samples = [enriched_dataset.loc[enriched_dataset["Ethnicity"] == g, "GPA"] for g in ethnicity_groups]
f_stat, p_val = stats.f_oneway(*ethnicity_samples)
print(f"Ethnicity vs GPA | ANOVA F={f_stat:.4f}, p={p_val:.4e}")

# Tutoring vs GradeClass
ct = pd.crosstab(enriched_dataset["Tutoring"], enriched_dataset["GradeClass"])
chi2, p_val, dof, expected = stats.chi2_contingency(ct)
print(f"Tutoring vs GradeClass | chi2={chi2:.4f}, p={p_val:.4e}, Cramer's V={cramers_v(ct):.4f}")

# CLT / bootstrap
boot_means = []
for _ in range(1000):
    sample = enriched_dataset["GPA"].sample(n=min(100, len(enriched_dataset)), replace=True)
    boot_means.append(sample.mean())

plt.figure(figsize=(7, 4))
sns.histplot(boot_means, kde=True)
plt.title("Bootstrap Sampling Distribution of Mean GPA")
plt.tight_layout()
plt.show()

ci_low, ci_high = np.percentile(boot_means, [2.5, 97.5])
print(f"95% bootstrap CI for mean GPA: ({ci_low:.4f}, {ci_high:.4f})")
# Out:
# Gender vs GPA | t=-0.6532, p=5.1367e-01, Cohen's d=-0.0267
# Ethnicity vs GPA | ANOVA F=0.9581, p=4.1159e-01
# Tutoring vs GradeClass | chi2=37.7516, p=1.2608e-07, Cramer's V=0.1256
# 95% bootstrap CI for mean GPA: (1.7388, 2.0873)

# %% [markdown]
# ## Regression Modeling
# - Multiple linear regression
# - Residual diagnostics
# - Holdout performance

# %%
ols_explanatory_features = [
    "StudyTimeWeekly",
    "Absences",
    "ParentalSupport",
    "Tutoring",
    "Inter_Support_x_Absences",
    "Inter_StudyTime_x_Gender",
]

X_reg = enriched_dataset[ols_explanatory_features]
y_reg = enriched_dataset["GPA"]

X_reg_train, X_reg_test, y_reg_train, y_reg_test = train_test_split(
    X_reg, y_reg, test_size=0.20, random_state=RANDOM_ANCHOR
)

X_reg_train_const = sm.add_constant(X_reg_train)
X_reg_test_const = sm.add_constant(X_reg_test)

ols_fitted_model = sm.OLS(y_reg_train, X_reg_train_const).fit()
reg_pred = ols_fitted_model.predict(X_reg_test_const)

print(ols_fitted_model.summary())
print(f"Test R²  : {r2_score(y_reg_test, reg_pred):.4f}")
print(f"Test RMSE: {np.sqrt(mean_squared_error(y_reg_test, reg_pred)):.4f}")
print(f"Test MAE : {mean_absolute_error(y_reg_test, reg_pred):.4f}")

residuals = y_reg_test - reg_pred

plt.figure(figsize=(6, 4))
sns.scatterplot(x=reg_pred, y=residuals)
plt.axhline(0, linestyle="--")
plt.title("Residuals vs Predicted GPA")
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
qqplot(ols_fitted_model.resid, line="45", fit=True)
plt.title("Q-Q Plot of OLS Residuals")
plt.tight_layout()
plt.show()

bp_test = het_breuschpagan(ols_fitted_model.resid, ols_fitted_model.model.exog)
print({"LM Stat": bp_test[0], "LM p-value": bp_test[1], "F Stat": bp_test[2], "F p-value": bp_test[3]})
print(f"Durbin-Watson: {durbin_watson(ols_fitted_model.resid):.4f}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GPA   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     4315.
# Date:                Sun, 14 Jun 2026   Prob (F-statistic):               0.00
# Time:                        11:43:12   Log-Likelihood:                 16.185
# No. Observations:                1913   AIC:                            -18.37
# Df Residuals:                    1906   BIC:                             20.53
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        2.6758      0.026    104.609      0.000       2.626       2.726
# StudyTimeWeekly              0.0289      0.001     26.082      0.000       0.027       0.031
# Absences                    -0.0995      0.001    -71.687      0.000      -0.102      -0.097
# ParentalSupport              0.1469      0.010     14.990      0.000       0.128       0.166
# Tutoring                     0.2621      0.012     21.874      0.000       0.239       0.286
# Inter_Support_x_Absences  7.129e-05      0.001      0.124      0.901      -0.001       0.001
# Inter_StudyTime_x_Gender     0.0005      0.001      0.501      0.616      -0.001       0.002
# ==============================================================================
# Omnibus:                        4.414   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.110   Jarque-Bera (JB):                4.026
# Skew:                           0.059   Prob(JB):                        0.134
# Kurtosis:                       2.809   Cond. No.                         219.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Test R²  : 0.9285
# Test RMSE: 0.2432
# Test MAE : 0.1857
# {'LM Stat': np.float64(4.311955162186429), 'LM p-value': np.float64(0.6345401379568711), 'F Stat': np.float64(0.7176470910961587), 'F p-value': np.float64(0.6354038558905544)}
# Durbin-Watson: 2.0487

# %% [markdown]
# ### Regression Findings
#
# The regression model was used to estimate the influence of study behavior, attendance, and support-related variables on GPA.
#
# Key points:
#
# - Positive coefficients indicate factors associated with GPA improvement.
# - Negative coefficients indicate factors associated with GPA decline.
# - Interaction terms capture moderation effects between support and attendance.
# - Model performance is evaluated using R², RMSE, and MAE.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

cv_model = LinearRegression()

cv_scores = cross_val_score(
    cv_model,
    X_reg,
    y_reg,
    cv=5,
    scoring='r2'
)

print("Cross Validation R² Scores:", cv_scores)
print("Average CV R²:", cv_scores.mean())
# Out:
# Cross Validation R² Scores: [0.93064094 0.92628776 0.92298347 0.93772788 0.93279495]
# Average CV R²: 0.9300869996982641

# %% [markdown]
# ## Binary Classification
# - High performer vs low performer
# - Logistic Regression
# - Random Forest
# - ROC curve

# %%
binary_features = [
    "Age", "Gender", "Ethnicity", "ParentalEducation", "StudyTimeWeekly",
    "Absences", "Tutoring", "ParentalSupport", "Extracurricular", "Sports",
    "Music", "Volunteering", "Support_Index", "Activity_Diversity"
]

X_bin = enriched_dataset[binary_features]
y_bin = enriched_dataset["High_Performer"]

X_train_b, X_test_b, y_train_b, y_test_b = train_test_split(
    X_bin, y_bin, test_size=0.20, random_state=RANDOM_ANCHOR, stratify=y_bin
)

scaler_b = StandardScaler()
X_train_b_scaled = scaler_b.fit_transform(X_train_b)
X_test_b_scaled = scaler_b.transform(X_test_b)

log_model = LogisticRegression(max_iter=2000, random_state=RANDOM_ANCHOR)
log_model.fit(X_train_b_scaled, y_train_b)
log_pred = log_model.predict(X_test_b_scaled)
log_prob = log_model.predict_proba(X_test_b_scaled)[:, 1]

rf_bin_model = RandomForestClassifier(n_estimators=200, random_state=RANDOM_ANCHOR)
rf_bin_model.fit(X_train_b, y_train_b)
rf_pred = rf_bin_model.predict(X_test_b)
rf_prob = rf_bin_model.predict_proba(X_test_b)[:, 1]

print("Logistic Regression")
print(f"Accuracy  : {accuracy_score(y_test_b, log_pred):.4f}")
print(f"Precision : {precision_score(y_test_b, log_pred):.4f}")
print(f"Recall    : {recall_score(y_test_b, log_pred):.4f}")
print(f"F1        : {f1_score(y_test_b, log_pred):.4f}")
print(f"AUROC     : {roc_auc_score(y_test_b, log_prob):.4f}")

print("\nRandom Forest")
print(f"Accuracy  : {accuracy_score(y_test_b, rf_pred):.4f}")
print(f"Precision : {precision_score(y_test_b, rf_pred):.4f}")
print(f"Recall    : {recall_score(y_test_b, rf_pred):.4f}")
print(f"F1        : {f1_score(y_test_b, rf_pred):.4f}")
print(f"AUROC     : {roc_auc_score(y_test_b, rf_prob):.4f}")

fpr_l, tpr_l, _ = roc_curve(y_test_b, log_prob)
fpr_r, tpr_r, _ = roc_curve(y_test_b, rf_prob)

plt.figure(figsize=(6, 4))
plt.plot(fpr_l, tpr_l, label="Logistic Regression")
plt.plot(fpr_r, tpr_r, label="Random Forest")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC Curves")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Logistic Regression
# Accuracy  : 0.9582
# Precision : 0.9231
# Recall    : 0.7500
# F1        : 0.8276
# AUROC     : 0.9857
#
# Random Forest
# Accuracy  : 0.9457
# Precision : 0.8519
# Recall    : 0.7188
# F1        : 0.7797
# AUROC     : 0.9764

# %% [markdown]
# ## Multi-class Classification
# - Predict GradeClass
# - Weighted F1 and confusion matrix

# %%
multi_features = binary_features.copy()
X_multi = enriched_dataset[multi_features]
y_multi = enriched_dataset["GradeClass"]

X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(
    X_multi, y_multi, test_size=0.20, random_state=RANDOM_ANCHOR, stratify=y_multi
)

scaler_m = StandardScaler()
X_train_m_scaled = scaler_m.fit_transform(X_train_m)
X_test_m_scaled = scaler_m.transform(X_test_m)

multi_log = LogisticRegression(max_iter=2000, multi_class="multinomial", random_state=RANDOM_ANCHOR)
multi_log.fit(X_train_m_scaled, y_train_m)
multi_pred = multi_log.predict(X_test_m_scaled)

print(f"Multi-class accuracy: {accuracy_score(y_test_m, multi_pred):.4f}")
print(f"Multi-class weighted F1: {f1_score(y_test_m, multi_pred, average='weighted'):.4f}")
print(confusion_matrix(y_test_m, multi_pred))
# Out:
# Multi-class accuracy: 0.7265
# Multi-class weighted F1: 0.7150
# [[  3   6   4   4   4]
#  [  6  23  20   3   2]
#  [  0  10  53  12   3]
#  [  0   1  26  39  17]
#  [  0   2   3   8 230]]
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %%
# Multi-Class Confusion Matrix Visualization

plt.figure(figsize=(6,5))

sns.heatmap(
    confusion_matrix(y_test_m, multi_pred),
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.title("Multi-Class Confusion Matrix")
plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation of Multi-Class Confusion Matrix
#
# The confusion matrix provides a detailed view of classification performance across all GradeClass categories. The diagonal cells represent correctly classified observations, while off-diagonal cells indicate misclassifications.
#
# A higher concentration of observations along the diagonal suggests stronger classification performance. Misclassification patterns help identify which grade categories are most difficult to distinguish and may reveal overlapping characteristics among student groups.
#
# The confusion matrix complements overall accuracy and weighted F1-score by providing class-level performance insights that are not visible from aggregate metrics alone.

# %% [markdown]
# ## Clustering Analysis
# - Find student archetypes
# - Use elbow and silhouette methods
# - Profile each cluster

# %%
cluster_vars = ["GPA", "Absences", "Support_Index", "Activity_Diversity", "StudyTimeWeekly"]
cluster_df = enriched_dataset[cluster_vars].copy()

scaler_c = StandardScaler()
cluster_scaled = scaler_c.fit_transform(cluster_df)

k_values = range(2, 9)
inertias = []
sil_scores = []

for k in k_values:
    km = KMeans(n_clusters=k, random_state=RANDOM_ANCHOR, n_init=15)
    labels = km.fit_predict(cluster_scaled)
    inertias.append(km.inertia_)
    sil_scores.append(silhouette_score(cluster_scaled, labels))

best_k = list(k_values)[int(np.argmax(sil_scores))]
print("Best k:", best_k)

plt.figure(figsize=(6, 4))
plt.plot(list(k_values), inertias, marker="o", label="Inertia")
plt.plot(list(k_values), sil_scores, marker="o", label="Silhouette")
plt.title("Cluster Search")
plt.xlabel("k")
plt.legend()
plt.tight_layout()
plt.show()

final_kmeans = KMeans(n_clusters=best_k, random_state=RANDOM_ANCHOR, n_init=15)
enriched_dataset["Cluster_ID"] = final_kmeans.fit_predict(cluster_scaled)

print(enriched_dataset["Cluster_ID"].value_counts().sort_index())
display(enriched_dataset.groupby("Cluster_ID")[cluster_vars].mean().round(3))
# Out:
# Best k: 2
# Cluster_ID
# 0    1202
# 1    1190
# Name: count, dtype: int64
#               GPA  Absences  Support_Index  Activity_Diversity  \
# Cluster_ID
# 0           1.143    21.617          2.296               1.007
# 1           2.677     7.394          2.552               1.076
#
#             StudyTimeWeekly
# Cluster_ID
# 0                     9.238
# 1                    10.311

# %% [markdown]
# ## Bayesian Network Modeling
# - Probabilistic reasoning
# - Conditional inference
# - Intervention-oriented interpretation

# %%
import pandas as pd
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.inference import VariableElimination

bn_df = enriched_dataset.copy()

bn_df["GPA_Bin"] = pd.qcut(bn_df["GPA"], q=3, labels=["Low", "Medium", "High"])
bn_df["StudyTime_Bin"] = pd.qcut(bn_df["StudyTimeWeekly"], q=3, labels=["Low", "Medium", "High"])
bn_df["Absence_Bin"] = pd.qcut(bn_df["Absences"], q=3, labels=["Low", "Medium", "High"])

for col in ["ParentalEducation", "ParentalSupport", "Tutoring", "Gender", "Ethnicity"]:
    bn_df[col] = bn_df[col].astype(str)

bn_model = DiscreteBayesianNetwork([
    ("ParentalEducation", "ParentalSupport"),
    ("ParentalSupport", "StudyTime_Bin"),
    ("StudyTime_Bin", "GPA_Bin"),
    ("Absence_Bin", "GPA_Bin"),
    ("Tutoring", "GPA_Bin"),
    ("Ethnicity", "ParentalSupport"),
])

# Defining the data subset for the estimator
estimator_data = bn_df[[
    "ParentalEducation", "ParentalSupport", "StudyTime_Bin",
    "Absence_Bin", "Tutoring", "Ethnicity", "GPA_Bin"
]]

# Instantiating the BayesianEstimator with the model and data
estimator = BayesianEstimator(bn_model, estimator_data)

# fetching the parameters (CPDs) from the estimator, passing prior_type
estimated_cpds = estimator.get_parameters(prior_type="BDeu")

# Adding the estimated CPDs to the model
bn_model.add_cpds(*estimated_cpds)

infer = VariableElimination(bn_model)

print(infer.query(
    variables=["GPA_Bin"],
    evidence={"Absence_Bin": "High", "Tutoring": str(bn_df["Tutoring"].min())}
))

print(infer.query(
    variables=["GPA_Bin"],
    evidence={"StudyTime_Bin": "High", "ParentalSupport": str(bn_df["ParentalSupport"].max())}
))
# Out:
# +-----------------+----------------+
# | GPA_Bin         |   phi(GPA_Bin) |
# +=================+================+
# | GPA_Bin(High)   |         0.0005 |
# +-----------------+----------------+
# | GPA_Bin(Low)    |         0.9073 |
# +-----------------+----------------+
# | GPA_Bin(Medium) |         0.0922 |
# +-----------------+----------------+
# +-----------------+----------------+
# | GPA_Bin         |   phi(GPA_Bin) |
# +=================+================+
# | GPA_Bin(High)   |         0.4142 |
# +-----------------+----------------+
# | GPA_Bin(Low)    |         0.2700 |
# +-----------------+----------------+
# | GPA_Bin(Medium) |         0.3158 |
# +-----------------+----------------+
# /tmp/ipykernel_6249/1365373560.py:30: FutureWarning: `pgmpy.estimators.BayesianEstimator` is deprecated and will be removed in v1.3.0. Please use `pgmpy.parameter_estimator.DiscreteBayesianEstimator` instead.
#   estimator = BayesianEstimator(bn_model, estimator_data)

# %% [markdown]
# ## Fairness and Intersectional Evaluation
# - Compare performance across demographic groups
# - Check whether the model behaves differently for different subgroups

# %%
fairness_eval = X_test_b.copy()
fairness_eval["y_true"] = y_test_b.values
fairness_eval["y_pred"] = log_pred

def group_report(df, group_col):
    rows = []
    for g in pd.Series(df[group_col]).dropna().unique():
        sub = df[df[group_col] == g]
        rows.append([
            g,
            len(sub),
            accuracy_score(sub["y_true"], sub["y_pred"]),
            recall_score(sub["y_true"], sub["y_pred"], zero_division=0),
        ])
    return pd.DataFrame(rows, columns=[group_col, "n", "accuracy", "recall"])

print("By Gender")
display(group_report(fairness_eval.assign(Gender=X_test_b["Gender"].values), "Gender").round(4))

print("By Ethnicity")
display(group_report(fairness_eval.assign(Ethnicity=X_test_b["Ethnicity"].values), "Ethnicity").round(4))
# Out:
# By Gender
#    Gender    n  accuracy  recall
# 0       1  253    0.9605  0.8158
# 1       0  226    0.9558  0.6538
# By Ethnicity
#    Ethnicity    n  accuracy  recall
# 0          1   91    0.9451  0.6667
# 1          0  235    0.9617  0.8065
# 2          2  107    0.9533  0.6667
# 3          3   46    0.9783  0.8333

# %% [markdown]
# ## Intervention Simulation
# - Simulate practical policy changes
# - Estimate expected GPA improvement

# %%
def predict_mean_gpa(df_):
    temp = df_.copy()
    temp["Inter_Support_x_Absences"] = temp["ParentalSupport"] * temp["Absences"]
    temp["Inter_StudyTime_x_Gender"] = temp["StudyTimeWeekly"] * temp["Gender"]
    X_temp = sm.add_constant(temp[ols_explanatory_features], has_constant="add")
    return ols_fitted_model.predict(X_temp).mean()

base_gpa = predict_mean_gpa(enriched_dataset)

scenarios = [("Baseline", base_gpa)]

scenario1 = enriched_dataset.copy()
scenario1["Absences"] = (scenario1["Absences"] * 0.80).round().astype(int)
scenarios.append(("Absences -20%", predict_mean_gpa(scenario1)))

scenario2 = enriched_dataset.copy()
scenario2["StudyTimeWeekly"] = scenario2["StudyTimeWeekly"] * 1.10
scenarios.append(("StudyTime +10%", predict_mean_gpa(scenario2)))

scenario3 = enriched_dataset.copy()
scenario3["ParentalSupport"] = scenario3["ParentalSupport"] + 1
scenario3["ParentalSupport"] = scenario3["ParentalSupport"].clip(upper=enriched_dataset["ParentalSupport"].max())
scenarios.append(("ParentalSupport +1", predict_mean_gpa(scenario3)))

scenario_results = pd.DataFrame(scenarios, columns=["Scenario", "Predicted Mean GPA"])
scenario_results["Delta vs Baseline"] = scenario_results["Predicted Mean GPA"] - base_gpa
display(scenario_results.round(4))
# Out:
#              Scenario  Predicted Mean GPA  Delta vs Baseline
# 0            Baseline              1.9065             0.0000
# 1       Absences -20%              2.1951             0.2887
# 2      StudyTime +10%              1.9349             0.0284
# 3  ParentalSupport +1              2.0387             0.1322

# %% [markdown]
# ## Final Model Comparison and Reporting Table

# %% [markdown]
# ### Model Comparison
#
# Multiple analytical approaches were evaluated because different techniques serve different purposes.
#
# - Regression models explain continuous GPA variation.
# - Classification models identify high-performing students.
# - Clustering reveals student archetypes.
# - Bayesian Networks support probabilistic reasoning.
#
# The following table summarizes predictive performance across the primary supervised learning models.

# %%
model_summary = pd.DataFrame([
    ["OLS Regression", r2_score(y_reg_test, reg_pred), np.sqrt(mean_squared_error(y_reg_test, reg_pred)), mean_absolute_error(y_reg_test, reg_pred)],
    ["Logistic Regression", accuracy_score(y_test_b, log_pred), precision_score(y_test_b, log_pred), recall_score(y_test_b, log_pred)],
    ["Random Forest Binary", accuracy_score(y_test_b, rf_pred), precision_score(y_test_b, rf_pred), recall_score(y_test_b, rf_pred)],
    ["Multi-class Logistic", accuracy_score(y_test_m, multi_pred), f1_score(y_test_m, multi_pred, average="weighted"), np.nan],
])
model_summary.columns = [
    "Model",
    "Primary Metric",
    "Secondary Metric",
    "Third Metric"
]

display(model_summary.round(4))
# Out:
#                   Model  Primary Metric  Secondary Metric  Third Metric
# 0        OLS Regression          0.9285            0.2432        0.1857
# 1   Logistic Regression          0.9582            0.9231        0.7500
# 2  Random Forest Binary          0.9457            0.8519        0.7188
# 3  Multi-class Logistic          0.7265            0.7150           NaN

# %% [markdown]
# ## Model Performance Visualization

# %%
comparison_plot = model_summary.copy()

comparison_plot.plot(
    x="Model",
    y="Metric 1",
    kind="bar",
    figsize=(8,5),
    legend=False
)

plt.ylabel("Primary Performance Metric")
plt.title("Model Performance Comparison")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Actual vs Predicted Plot for Regression

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_reg_test, reg_pred, alpha=0.6)

plt.plot(
    [y_reg_test.min(), y_reg_test.max()],
    [y_reg_test.min(), y_reg_test.max()],
    'r--'
)

plt.xlabel("Actual GPA")
plt.ylabel("Predicted GPA")
plt.title("Actual vs Predicted GPA")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Importance Plot

# %%
feature_importance = pd.DataFrame({
    "Feature": binary_features,
    "Importance": rf_bin_model.feature_importances_
})

feature_importance = feature_importance.sort_values(
    "Importance",
    ascending=False
)

plt.figure(figsize=(8,5))
sns.barplot(
    data=feature_importance.head(10),
    x="Importance",
    y="Feature"
)

plt.title("Top 10 Random Forest Feature Importances")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Cluster Visualization

# %%
plt.figure(figsize=(7,5))

sns.scatterplot(
    data=enriched_dataset,
    x="StudyTimeWeekly",
    y="GPA",
    hue="Cluster_ID",
    palette="tab10"
)

plt.title("Student Archetypes Identified by Clustering")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Intervention Simulation Plot

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=scenario_results,
    x="Scenario",
    y="Predicted Mean GPA"
)

plt.title("Impact of Simulated Interventions on GPA")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %%
# =========================
# Model selection logic
# =========================

# 1) Best regression model: higher R², lower RMSE/MAE
regression_candidates = pd.DataFrame([
    {
        "Model": "OLS Regression",
        "R2": r2_score(y_reg_test, reg_pred),
        "RMSE": np.sqrt(mean_squared_error(y_reg_test, reg_pred)),
        "MAE": mean_absolute_error(y_reg_test, reg_pred),
    }
])

best_regression_model = regression_candidates.sort_values(
    by=["R2", "RMSE", "MAE"],
    ascending=[False, True, True]
).iloc[0]

# 2) Best binary classification model: higher F1, AUROC, Accuracy
binary_candidates = pd.DataFrame([
    {
        "Model": "Logistic Regression",
        "Accuracy": accuracy_score(y_test_b, log_pred),
        "Precision": precision_score(y_test_b, log_pred),
        "Recall": recall_score(y_test_b, log_pred),
        "F1": f1_score(y_test_b, log_pred),
        "AUROC": roc_auc_score(y_test_b, log_prob),
    },
    {
        "Model": "Random Forest",
        "Accuracy": accuracy_score(y_test_b, rf_pred),
        "Precision": precision_score(y_test_b, rf_pred),
        "Recall": recall_score(y_test_b, rf_pred),
        "F1": f1_score(y_test_b, rf_pred),
        "AUROC": roc_auc_score(y_test_b, rf_prob),
    }
])

best_binary_model = binary_candidates.sort_values(
    by=["F1", "AUROC", "Accuracy"],
    ascending=[False, False, False]
).iloc[0]

# 3) Best multi-class model: higher weighted F1 and accuracy
multi_candidates = pd.DataFrame([
    {
        "Model": "Multi-class Logistic",
        "Accuracy": accuracy_score(y_test_m, multi_pred),
        "Weighted_F1": f1_score(y_test_m, multi_pred, average="weighted"),
    }
])

best_multiclass_model = multi_candidates.sort_values(
    by=["Weighted_F1", "Accuracy"],
    ascending=[False, False]
).iloc[0]

print("Best regression model:", best_regression_model["Model"])
print("Best binary classification model:", best_binary_model["Model"])
print("Best multi-class model:", best_multiclass_model["Model"])
# Out:
# Best regression model: OLS Regression
# Best binary classification model: Logistic Regression
# Best multi-class model: Multi-class Logistic

# %%
# =========================
# Highlighted model summary
# =========================

highlight_rows = [
    ["Regression", best_regression_model["Model"],
     f"R²={best_regression_model['R2']:.4f}",
     f"RMSE={best_regression_model['RMSE']:.4f}",
     f"MAE={best_regression_model['MAE']:.4f}"],

    ["Binary Classification", best_binary_model["Model"],
     f"Accuracy={best_binary_model['Accuracy']:.4f}",
     f"F1={best_binary_model['F1']:.4f}",
     f"AUROC={best_binary_model['AUROC']:.4f}"],

    ["Multi-class Classification", best_multiclass_model["Model"],
     f"Accuracy={best_multiclass_model['Accuracy']:.4f}",
     f"Weighted F1={best_multiclass_model['Weighted_F1']:.4f}",
     "-"],
]

highlight_df = pd.DataFrame(
    highlight_rows,
    columns=["Task", "Highlighted Model", "Metric 1", "Metric 2", "Metric 3"]
)

display(highlight_df)
# Out:
#                          Task     Highlighted Model         Metric 1  \
# 0                  Regression        OLS Regression        R²=0.9285
# 1       Binary Classification   Logistic Regression  Accuracy=0.9582
# 2  Multi-class Classification  Multi-class Logistic  Accuracy=0.7265
#
#              Metric 2      Metric 3
# 0         RMSE=0.2432    MAE=0.1857
# 1           F1=0.8276  AUROC=0.9857
# 2  Weighted F1=0.7150             -

# %% [markdown]
# ### Best Performing Models
#
# For GPA prediction, OLS Regression achieved an R² of 0.9285, indicating that approximately 92.85% of the variation in GPA is explained by the selected predictors.
#
# For binary classification, Logistic Regression achieved an accuracy of 95.82% and an AUROC of 0.9857, demonstrating excellent discrimination between high-performing and low-performing students.
#
# For multi-class GradeClass prediction, Logistic Regression achieved a weighted F1-score of 0.7150, indicating moderate classification performance across multiple achievement categories.
#
# These findings suggest that interpretable statistical models perform exceptionally well on this dataset while maintaining transparency and ease of interpretation.

# %% [markdown]
# ## Limitations
#
# - Dataset is synthetic.
# - Correlation does not imply causation.
# - Some educational factors are unavailable.
# - Results may not generalize to all student populations.

# %% [markdown]
# ## Conclusion and Recommendations
#
# This study investigated the factors influencing secondary student performance using statistical analysis, machine learning, clustering, and Bayesian Networks.
#
# The OLS Regression model achieved an R² of 0.9285, indicating strong predictive capability for GPA. Logistic Regression achieved 95.82% classification accuracy and an AUROC of 0.9857 for identifying high-performing students.
#
# Across all analyses, study time, absenteeism, and parental support emerged as the most influential variables. Increased study time was associated with improved academic outcomes, while excessive absences consistently reduced GPA. Support-related variables demonstrated positive effects and appeared to moderate attendance-related risk.
#
# Cluster analysis revealed distinct student archetypes, suggesting that intervention strategies should be tailored to specific student groups. Bayesian Networks further enabled probabilistic reasoning regarding intervention effectiveness and future academic outcomes.
#
# The results demonstrate that combining statistical inference with machine learning provides a robust framework for understanding student performance and developing targeted educational interventions.
